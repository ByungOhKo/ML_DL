# %%
# %matplotlib inline

# %%
from numpy import random as r
I = r.rand(256, 256)
print(I)
# Out:
# [[0.73836824 0.82695728 0.78969464 ... 0.40376097 0.80308424 0.11464518]
#  [0.38640731 0.82855973 0.49105571 ... 0.16678499 0.56392721 0.20474814]
#  [0.23519372 0.91997215 0.26946813 ... 0.31953759 0.52881331 0.56658845]
#  ...
#  [0.42018656 0.57611341 0.3444059  ... 0.47877391 0.33634711 0.16551031]
#  [0.15433714 0.39911346 0.32491883 ... 0.84850399 0.18619911 0.13563095]
#  [0.65501396 0.63080017 0.76548692 ... 0.00711231 0.87027171 0.31947885]]

# %%
from matplotlib import pyplot as p
p.imshow(I)
p.show()

# %%
print(I[100])
I[100] = 1.0
print(I[100])
p.imshow(I, cmap='gray')
# Out:
# [0.65726868 0.3407875  0.71631158 0.47557784 0.50913135 0.99744792
#  0.91674795 0.02761898 0.63680246 0.68815017 0.21212012 0.31824668
#  0.00618994 0.63355238 0.337394   0.75672538 0.07559575 0.59542762
#  0.55393899 0.89598117 0.15164242 0.85913181 0.21658331 0.4617632
#  0.51959889 0.86731481 0.53750112 0.20621721 0.98823403 0.90110546
#  0.76617078 0.02449992 0.79043224 0.13732213 0.03551352 0.87448537
#  0.73322577 0.88362628 0.63338016 0.5149066  0.14229132 0.39672692
#  0.4320373  0.36189023 0.56871691 0.49376666 0.98864985 0.99905189
#  0.35980922 0.55499666 0.78718448 0.14097656 0.73031418 0.53356448
#  0.27045856 0.87957405 0.82239181 0.48506208 0.90795707 0.19370142
#  0.99937613 0.38605671 0.67914553 0.01747393 0.66391151 0.96560582
#  0.28294236 0.05554048 0.20979846 0.63584642 0.63446513 0.36856133
#  0.62301077 0.02100894 0.79232006 0.46434502 0.98092268 0.98834551
#  0.36277135 0.43640183 0.63857771 0.59809337 0.2113794  0.21078328
# ...

# %%
I[100] = 1.0
print(I.shape)
print(I.ndim)
# Out:
# (256, 256)
# 2

# %%
I = r.rand(256,256,3)
print(I.shape)
print(I.ndim)
p.imshow(I)
# Out:
# (256, 256, 3)
# 3
